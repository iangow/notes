# %%
url = ("https://raw.githubusercontent.com/WillAyd/"
       "Pandas-Cookbook-Third-Edition/refs/heads/"
       "main/data/sgi_monitoring.parquet")
# !wget {url}
# Out:
# --2026-01-18 10:19:49--  https://raw.githubusercontent.com/WillAyd/Pandas-Cookbook-Third-Edition/refs/heads/main/data/sgi_monitoring.parquet
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8002::154, 2606:50c0:8001::154, 2606:50c0:8000::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8002::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102436915 (98M) [application/octet-stream]
# Saving to: ‘sgi_monitoring.parquet’
#
# sgi_monitoring.parq 100%[===================>]  97.69M  80.9MB/s    in 1.2s
#
# 2026-01-18 10:19:52 (80.9 MB/s) - ‘sgi_monitoring.parquet’ saved [102436915/102436915]
